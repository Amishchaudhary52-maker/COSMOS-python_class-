# %%
shopping_list=["copy","pen","book"]
print(shopping_list)
shopping_list.append("Notebook")
print(shopping_list)
shopping_list.remove("copy")
print(shopping_list)
if "pen" in shopping_list:
    print("pen is in shopping_list")
else:
    print("pen is not in shopping_list")

number = len(shopping_list)

print(number)

for len in shopping_list:
    print(len)
# Out:
# ['copy', 'pen', 'book']
# ['copy', 'pen', 'book', 'Notebook']
# ['pen', 'book', 'Notebook']
# pen is in shopping_list
# 3
# pen
# book
# Notebook

# %%
shopping_list=["copy","pen","book"]
print(shopping_list)
shopping_list.append("Notebook")
print(shopping_list)
shopping_list.remove("copy")
print(shopping_list)
if "pen" in shopping_list:
    print("pen is in shopping_list")
else:
    print("pen is not in shopping_list")

number = len(shopping_list)

print("no. of item:",number)

for i in range (len(shopping_list)):
    idx=i+1
    item=shopping_list[i]
    print(f"{idx}.{item}")
# Out:
# ['copy', 'pen', 'book']
# ['copy', 'pen', 'book', 'Notebook']
# ['pen', 'book', 'Notebook']
# pen is in shopping_list
# no. of item: 3
# 1.pen
# 2.book
# 3.Notebook

# %% [markdown]
# ## file Handling

# %%
with open("writenote.txt","w") as f:
    f.write("Amish chaudhary")
with open("writenote.txt","r") as f:
    content=f.read()
    print(content)

# %% [markdown]
# ## Error handling

# %%
try:
    result= 10/0
except ZeroDivisionError:
    print("cannot divide by zero.")

# %%
def save_note():
  note=input("enter your note:")
  with open("note.txt","w") as f:
    f.write(note)

def read_note():
 with open("note.txt","r") as f:
     content=f.read()
     print(content)

 file_name=input(" enter file name to read")

try: 
    with open(file_name,"r") as f:
     content=f.read()
     print(content)
except FileNotFoundError:
    print("file not found.")
def repeat_note():
   note=input("enter your note:")
   

save_note()
read_note()
repeat_note()
# Out:
# amish
# amish

# %%
import math
import random
print(math.sqrt(16))
print(math.pi)
print(math.ceil(4.2))
print(random.randint(1,6)) # 1-6 dice roll
print(random.choice(["rock","paper","scissors"]))
# Out:
# 4.0
# 3.141592653589793
# 5
# 1
# rock

# %%
import pandas as pd
data={
    "name":["Alice","Bob","Carol"],
    "age" :[25,30,35]
}
df= pd.DataFrame(data)
print(df)
print(df["age"].mean())
# Out:
#     name  age
# 0  Alice   25
# 1    Bob   30
# 2  Carol   35
# 30.0
