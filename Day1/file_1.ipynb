# %%
num1=float(input("enter any  number"))
num2=float(input("enter any number"))
total =num1+num2
average=total/2.0
print("total:",total)
print("average:",average)
# Out:
# total: 7.0
# average: 3.5

# %% [markdown]
# conditional_example.py

# %%
marks=72
if marks >= 80:
    print("grade A")
elif marks >=60:
    print("grade B")
else:
    print("Needs Improvement")
# Out:
# grade B

# %% [markdown]
# ## looping

# %% [markdown]
# ### forloop_eg

# %%
for i in range(5):
   print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ### whileloop_eg

# %%
count =0
while count<3:
    count +=1
    print(count)
# Out:
# 1
# 2
# 3

# %% [markdown]
# ##function_example.py

# %%
#1.Define function
def greet(name):
    """return a greeting message"""
    return f"Hello,{name}!"
    #2.call function &print
message = greet("Amish")
print(message)
# Out:
# Hello,Amish!

# %% [markdown]
# ## structure_example

# %%
#1.Dictonary :key-value pairs
student={
    "name":"Amish chauhdary",
    "Gpa": 3.8
}
print(student)

#2.set:unique elements only
tags={"py", "py" , "lab"}
print(tags)
# Out:
# {'name': 'Amish chauhdary', 'Gpa': 3.8}
# {'lab', 'py'}

# %% [markdown]
# conditional_exe

# %%
n=int(input("enter any number"))
r=n%2
if r==0:
    print("even number")
else:
    print("odd number")
# Out:
# even number

# %% [markdown]
# using function

# %%
n=int(input("enter any number"))

def checkoddeven(n):
    if n%2==0:
       return "this number is even{n}"
    else:
        return " this number is odd{n}"


out = checkoddeven(n)
print(out)
# Out:
# this number is even{n}
